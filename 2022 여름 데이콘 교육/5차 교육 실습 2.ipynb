# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#실습2" data-toc-modified-id="실습2-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>실습2</a></span></li><li><span><a href="#데이터-살펴보기" data-toc-modified-id="데이터-살펴보기-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>데이터 살펴보기</a></span><ul class="toc-item"><li><span><a href="#데이터-준비" data-toc-modified-id="데이터-준비-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>데이터 준비</a></span></li><li><span><a href="#데이터-확인" data-toc-modified-id="데이터-확인-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>데이터 확인</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#target" data-toc-modified-id="target-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>target</a></span></li><li><span><a href="#Insight" data-toc-modified-id="Insight-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Insight</a></span></li><li><span><a href="#따릉이-대여량이-8000이하인-값,-초과인-값의-feature-비교" data-toc-modified-id="따릉이-대여량이-8000이하인-값,-초과인-값의-feature-비교-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>따릉이 대여량이 8000이하인 값, 초과인 값의 feature 비교</a></span></li><li><span><a href="#비교를-위한-시각화" data-toc-modified-id="비교를-위한-시각화-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>비교를 위한 시각화</a></span><ul class="toc-item"><li><span><a href="#인사이트" data-toc-modified-id="인사이트-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>인사이트</a></span></li></ul></li><li><span><a href="#통계치-분석-시각화-EDA" data-toc-modified-id="통계치-분석-시각화-EDA-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>통계치 분석 시각화 EDA</a></span><ul class="toc-item"><li><span><a href="#인사이트-도출" data-toc-modified-id="인사이트-도출-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>인사이트 도출</a></span></li><li><span><a href="#precipitation_form-그래프" data-toc-modified-id="precipitation_form-그래프-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>precipitation_form 그래프</a></span></li></ul></li><li><span><a href="#가설-검정" data-toc-modified-id="가설-검정-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>가설 검정</a></span><ul class="toc-item"><li><span><a href="#가설1:-따릉이-대여량은-강수여부에-큰-영향을-받을-것이다." data-toc-modified-id="가설1:-따릉이-대여량은-강수여부에-큰-영향을-받을-것이다.-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>가설1: 따릉이 대여량은 강수여부에 큰 영향을 받을 것이다.</a></span></li><li><span><a href="#가설2.-풍속이-강한-날은-대여량이-낮아질-것이다." data-toc-modified-id="가설2.-풍속이-강한-날은-대여량이-낮아질-것이다.-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>가설2. 풍속이 강한 날은 대여량이 낮아질 것이다.</a></span></li><li><span><a href="#가설3.-최저기온-낮은-날에는-따릉이-대여량이-낮아질-것이다." data-toc-modified-id="가설3.-최저기온-낮은-날에는-따릉이-대여량이-낮아질-것이다.-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>가설3. 최저기온 낮은 날에는 따릉이 대여량이 낮아질 것이다.</a></span></li><li><span><a href="#인사이트-도출-(정리)" data-toc-modified-id="인사이트-도출-(정리)-3.6.4"><span class="toc-item-num">3.6.4&nbsp;&nbsp;</span>인사이트 도출 (정리)</a></span></li></ul></li></ul></li><li><span><a href="#데이터-처리" data-toc-modified-id="데이터-처리-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>데이터 처리</a></span><ul class="toc-item"><li><span><a href="#feature-engineering" data-toc-modified-id="feature-engineering-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>feature engineering</a></span></li><li><span><a href="#feature-selection" data-toc-modified-id="feature-selection-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>feature selection</a></span></li></ul></li><li><span><a href="#모델링2" data-toc-modified-id="모델링2-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>모델링2</a></span></li></ul></div>

# %% [markdown]
# # 실습2

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
# 코랩에서 한글 보이게 하려고 sudo로 뭐 설치한 다음에는
# 런타임 다시시작

# %% [markdown]
# # 데이터 살펴보기

# %% [markdown]
# ## 데이터 준비

# %%
# 데이터 준비 - 로드
train = pd.read_csv('./따릉이 data/train.csv')
test = pd.read_csv('./따릉이 data/test.csv')
submission = pd.read_csv('./따릉이 data/sample_submission.csv')

# %% [markdown]
# ## 데이터 확인

# %%
train.head()
test.head()
submission.head()
# Out:
#     date_time  number_of_rentals
# 0  2021-04-01                  0
# 1  2021-04-02                  0
# 2  2021-04-03                  0
# 3  2021-04-04                  0
# 4  2021-04-05                  0

# %%
train.shape
# Out:
# (273, 10)

# %% [markdown]
# # EDA
# 시각화

# %% [markdown]
# ## target
# 회귀문제이면 타겟을 먼저 살펴봐야한다.

# %%
plt.figure(dpi = 150)
x = train['number_of_rentals'].index
y = train['number_of_rentals'].values

plt.title('일별 따릉이 대여량')
plt.xlabel('일별')
plt.ylabel('따릉이 대여량')

plt.plot(x, y)

# %%
# 꾸준한 증가세
# 규칙적인 이상치 - 상식적으로 날씨 (비), 또는 생각을 해보자면 주말..?(평일에는 타고 출퇴근, 주말에는 안탐)

# %% [markdown]
# ## Insight
#
# 1. 시간이 흐를 수록 대여량이 증가하고 있다.
# 2. 이상치가 존재한다 -> 날씨에 영향을 받은 것일까?
# 3. 평일에는 출근을 하니까 대여량이 주말보다 많을 것이다.

# %%
### 2 번째, 이상치에 대한 인사이트 확인

# %%
plt.figure(dpi = 150)
x = train['number_of_rentals'].index
y = train['number_of_rentals'].values

plt.title('일별 따릉이 대여량 (이상치에 대한 인사이트 탐구)')
plt.xlabel('일별')
plt.ylabel('따릉이 대여량')

plt.hlines(y = 8000, xmin = 0, xmax = len(x), color = 'red', linestyle = ':') # 혹은 dotted

plt.plot(x, y)

# %% [markdown]
# ## 따릉이 대여량이 8000이하인 값, 초과인 값의 feature 비교

# %%
train[train['number_of_rentals']<=8000]
# Out:
#       date_time  wind_direction  sky_condition  precipitation_form  \
# 4    2018-04-05          95.905          4.000               0.723
# 7    2018-04-08         200.939          2.405               0.054
# 22   2018-04-23          79.554          4.000               1.000
# 41   2018-05-12         154.541          3.946               0.588
# 45   2018-05-16         191.108          4.000               0.797
# 46   2018-05-17         205.378          4.000               1.000
# 86   2018-06-26         181.939          3.851               0.723
# 220  2020-05-09         144.142          4.000               1.000
#
#      wind_speed  humidity  low_temp  high_temp  Precipitation_Probability  \
# 4         3.186    73.784     5.875     10.421                     63.378
# 7         3.865    53.243     4.312     14.211                     15.676
# 22        4.127    81.182     9.250     15.158                     75.608
# ...

# %%
train[train['number_of_rentals']<=8000].mean()
# Out:
# wind_direction                156.688250
# sky_condition                   3.775250
# precipitation_form              0.735625
# wind_speed                      3.344000
# humidity                       76.786125
# low_temp                       13.023500
# high_temp                      19.375000
# Precipitation_Probability      62.736500
# number_of_rentals            5005.500000
# dtype: float64

# %%
train[train['number_of_rentals']>8000].mean()
# Out:
# wind_direction                 204.141540
# sky_condition                    2.243366
# precipitation_form               0.081804
# wind_speed                       2.454909
# humidity                        56.140491
# low_temp                        13.818547
# high_temp                       23.505781
# Precipitation_Probability       15.493698
# number_of_rentals            61222.358491
# dtype: float64

# %%
# 수치만으로 파악하기엔 가시성 bad
# 시각화 하도록 한다.

x = train[train['number_of_rentals']<=8000].drop(['date_time', 'number_of_rentals'], axis = 1).mean().index
y = train[train['number_of_rentals']<=8000].drop(['date_time', 'number_of_rentals'], axis = 1).mean().values
# date_time은 명목변수이기 때문에 시각화에서 제거.

plt.figure(figsize = (18,5))
plt.title('대여량 8000 이하인 날의 피쳐들의 평균 값')
plt.xlabel('피쳐')
plt.xlabel('수치')

plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %%
x = train[train['number_of_rentals']>8000].drop(['date_time', 'number_of_rentals'], axis = 1).mean().index
y = train[train['number_of_rentals']>8000].drop(['date_time', 'number_of_rentals'], axis = 1).mean().values
# date_time은 명목변수이기 때문에 시각화에서 제거.

plt.figure(figsize = (18,5))
plt.title('대여량 8000 이상인 날의 피쳐들의 평균 값')
plt.xlabel('피쳐')
plt.xlabel('수치')

plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %%
# 현재로써는 8000 이하와 초과 비교가 잘 안됨.
# 비교를 위한 시각화 다시.

# %% [markdown]
# ## 비교를 위한 시각화

# %%
[low.values[0], high.values[0]]
# Out:
# [156.68824999999998, 204.14153962264152]

# %%
low = train[train['number_of_rentals']<=8000].mean()
high = train[train['number_of_rentals']>8000].mean()
# date_time은 명목변수이기 때문에 시각화에서 제거.

x = ['8000<=' + low.index[0], '8000>' + high.index[0]]
y = [low.values[0], high.values[0]]

plt.figure(figsize = (8,5))
plt.title(low.index[0] + '의 평균')
plt.xlabel('피쳐')
plt.ylabel('수치')

plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
def compare(idx):
    x = ['8000<=' + low.index[idx], '8000>' + high.index[idx]]
    y = [low.values[idx], high.values[idx]]

    # plt.figure(figsize = (18,5))
    plt.title(low.index[idx] + '의 평균')
    plt.xlabel('피쳐')
    plt.ylabel('수치')
    plt.bar(x, y)

# %%
compare(1)

# %% [markdown]
# <8
# <8
# <8 강수 형태에서 유의미한 수치를 보임.

# %% [markdown]
# ### 인사이트
# 강수형태와 강수확률에 따릉이 대여량에 따라서 큰 차이가 있는 것을 확인

# %% [markdown]
# ## 통계치 분석 시각화 EDA

# %%
train.describe() # 총 8개의 통계치 출력
# 한 눈에 이해 어렵, 따라서 시각화 필요
# Out:
#        wind_direction  sky_condition  precipitation_form  wind_speed  \
# count      273.000000     273.000000          273.000000  273.000000
# mean       202.750967       2.288256            0.100963    2.480963
# std         56.659232       0.961775            0.203193    0.884397
# min         57.047000       1.000000            0.000000    0.753000
# 25%        171.541000       1.405000            0.000000    1.820000
# 50%        209.774000       2.167000            0.000000    2.411000
# 75%        238.412000       3.000000            0.088000    2.924000
# max        321.622000       4.000000            1.000000    5.607000
#
#          humidity    low_temp   high_temp  Precipitation_Probability  \
# count  273.000000  273.000000  273.000000                 273.000000
# mean    56.745491   13.795249   23.384733                  16.878103
# std     12.351268    5.107711    5.204605                  16.643772
# ...

# %% [markdown]
# n 사분위수 : 각 사분위 지점의 수

# %%
plt.rcParams['font.size'] = 15
data = train.describe().loc['min':'max', 'number_of_rentals']

plt.title('number_of_rentals')
plt.plot(data, color = 'red', marker = 'o')
plt.grid(True)

# %%
def describ(name): # 변수명 자체 사용, 따라서 인자에 name
    plt.rcParams['font.size'] = 15
    data = train.describe().loc['min':'max', name]

    plt.title(name)
    plt.plot(data, color = 'red', marker = 'o')
    plt.grid(True)

# %%
describ('number_of_rentals')

# %%
describ('precipitation_form') # 75%부터 급격한 증가, 비정상적인 분포 따라서 따로 다시 봐야할 필요가 있음.

# %%
describ('low_temp')

# %%
describ('wind_speed')

# %%
describ('high_temp')

# %% [markdown]
# ### 인사이트 도출
# 강수 형태 precipitation_form은 최솟값부터 75% 구간까지는 평탄한 것에 비해 <br>
#
# 75%부터 max까지는 급격한 폭이 보인다. <br>
# ==> 다시 살펴보기

# %% [markdown]
# ### precipitation_form 그래프

# %%
plt.figure(figsize = (30,6))
plt.plot(train['precipitation_form'], color = 'g')

plt.ylabel('강수 형태')
plt.xlabel('월별')

# 뚜렷한 패턴 안보임.
# 비오는 것 자체에 뚜렷한 패턴이 있는 건 아님.
# Out:
# Text(0.5, 0, '월별')

# %%
# data type이 object인 것은 이번 PBL까지는 사용하지 않음.

# %% [markdown]
# ## 가설 검정
# 분석 시작 전 세웠던 가설
# 1. 강수
# 2. 풍속
# 3. 최저기온
#
# 검정 by scatter (상관관계 볼거니까)

# %% [markdown]
# ### 가설1: 따릉이 대여량은 강수여부에 큰 영향을 받을 것이다.

# %%
plt.figure(figsize=(15, 5))
plt.scatter(y = train['number_of_rentals'], x = train['precipitation_form'])
plt.xlabel('강수여부')
plt.ylabel('따릉이 대여량')
# 0에 몰려있으며, 반비례관계이다.
# 비 많이, 대여 적
# Out:
# Text(0, 0.5, '따릉이 대여량')

# %%
import seaborn as sns
plt.figure(figsize = (15, 5))
sns.regplot(x='precipitation_form', y='number_of_rentals', data = train)
# 선형회귀 추세선
## 을 통해 반비례관계 확인.
# Out:
# <AxesSubplot:xlabel='precipitation_form', ylabel='number_of_rentals'>

# %% [markdown]
# ### 가설2. 풍속이 강한 날은 대여량이 낮아질 것이다.

# %%
plt.figure(figsize=(15, 5))
plt.scatter(y = train['number_of_rentals'], x = train['wind_speed'])
plt.xlabel('풍속')
plt.ylabel('따릉이 대여량')
# 반비례관계이다.
# 풍속 수치 적, 대여량 많
# 상관관계가 높아보이지는 않음.
# regplot을 통해 확인한다.
# Out:
# Text(0, 0.5, '따릉이 대여량')

# %%
plt.figure(figsize = (15, 5))
sns.regplot(x='wind_speed', y='number_of_rentals', data = train)
# 선형회귀 추세선
## 을 통해 반비례관계 확인.
# Out:
# <AxesSubplot:xlabel='wind_speed', ylabel='number_of_rentals'>

# %% [markdown]
# ### 가설3. 최저기온 낮은 날에는 따릉이 대여량이 낮아질 것이다.

# %%
plt.figure(figsize=(15, 5))
plt.scatter(y = train['number_of_rentals'], x = train['low_temp'])
plt.xlabel('최저기온')
plt.ylabel('따릉이 대여량')
# 특정 관계가 보이지는 않는다.
# Out:
# Text(0, 0.5, '따릉이 대여량')

# %%
plt.figure(figsize = (15, 5))
sns.regplot(x='low_temp', y='number_of_rentals', data = train)
# 선형회귀 추세선
## 을 통해 약간의 비례관계 확인. (대체적으로 정비례관계, 가설이 틀린 것만은 아니다.)
# Out:
# <AxesSubplot:xlabel='low_temp', ylabel='number_of_rentals'>

# %% [markdown]
# ### 인사이트 도출 (정리)
# 시각화를 통하여 `강수형태`, `풍속`, `최저기온`이 따릉이 대여량에 영향을 미친다는 것을 확인하였다.

# %% [markdown]
# 다음시간 ==> EDA를 따른 Feature Engineering 진행

# %% [markdown]
# # 데이터 처리
# ## feature engineering
# ## feature selection

# %%
train = train.drop(['date_time'], axis = 1)
test = test.drop(['date_time'], axis = 1)

# %%
train.columns
# Out:
# Index(['wind_direction', 'sky_condition', 'precipitation_form', 'wind_speed',
#        'humidity', 'low_temp', 'high_temp', 'Precipitation_Probability',
#        'number_of_rentals'],
#       dtype='object')

# %%
X = train[['wind_direction', 'sky_condition', 'precipitation_form', 'wind_speed',
       'humidity', 'low_temp', 'high_temp', 'Precipitation_Probability']]
y = train['number_of_rentals']

# %% [markdown]
# # 모델링2
# - 모델 선택 (랜덤포레스트)
# - 모델 실습 기본 포맷

# %%
## 모델 선택
from sklearn.ensemble import RandomForestRegressor

# 모델 선언
model = RandomForestRegressor()

# 모델 학습
model.fit(X, y)

# 예측
predict = model.predict(test)

# %%
predict[:10]
# Out:
# array([56572.45, 36152.97, 42769.29, 25608.71, 66513.45, 68172.69,
#        70392.01, 63087.22, 67355.9 , 75487.72])

# %% [markdown]
# Q: 혹시 마지막에 제출 결과 rf 성능이 별로라고 하신게 맞을까요?
#
#
# A: 네 맞습니다 의사결정나무보다는 성능이 미세하게 좋아졌지만 평균값을 넣은 것보다는 성능이 좋지 않으므로 유의미하지않은 결과입니다
#
#
# Q: 궁금한 것이 있는데, 매번 데이터의 평균값을 제출한 결과를 비교해야 하는 것인가요?
#
# A: 아뇨 평균값은 절대적인 지표가 아닙니다. 이해를 돕기위해서 말씀드린 것 입니다.
